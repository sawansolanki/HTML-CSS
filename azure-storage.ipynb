# %%
! pip install python-dotenv

# %%
! pip install azure
# Out:
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\sawan.solanki\Anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\sawan.solanki\\AppData\\Local\\Temp\\pip-install-k4k2_tlb\\dotenv_e730181c34f04211a44dd44e3ec34e0c\\setup.py'"'"'; __file__='"'"'C:\\Users\\sawan.solanki\\AppData\\Local\\Temp\\pip-install-k4k2_tlb\\dotenv_e730181c34f04211a44dd44e3ec34e0c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\sawan.solanki\AppData\Local\Temp\pip-pip-egg-info-eykd4rwf'
#          cwd: C:\Users\sawan.solanki\AppData\Local\Temp\pip-install-k4k2_tlb\dotenv_e730181c34f04211a44dd44e3ec34e0c\
#     Complete output (1591 lines):
# ...

# %%
import os
from dotenv import load_dotenv
from azure.common.credentials import ServicePrincipalCredentials
from azure.mgmt.resource import ResourceManagementClient
from azure.mgmt.storage import StorageManagementClient
from azure.mgmt.storage.models import StorageAccountCreateParameters, SkuName, Sku, Kind

# %%
! export subscription_id = "8b4189e4-9b8a-4fa6-b5a8-8760ee116f78"
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %%
subscription_id = "8b4189e4-9b8a-4fa6-b5a8-8760ee116f78"
client_id = ""
secret = ""
tenant = "638456b8-8343-4e48-9ebe-4f5cf9a1997d"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 subscription_id = os.environ["subscription_id"]
#       2 client_id = os.environ["client_id"]
#       3 secret = os.environ["secret"]
#
# File ~\Anaconda3\lib\os.py:679, in _Environ.__getitem__(self, key)
#     676     value = self._data[self.encodekey(key)]
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'subscription_id'

# %%
resource_group           = "RG-COMPASS"
location                 = "eastus-2"
storage_account_name     = "sa1pythonstrg"

# %%
credentials = ServicePrincipalCredentials(
    client_id= client_id,
    secret=secret,
    tenant=tenant
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       1 credentials = ServicePrincipalCredentials(
# ----> 2     client_id= client_id,
#       3     secret=secret,
#       4     tenant=tenant
#       5 )
#
# NameError: name 'client_id' is not defined

# %%
client = ResourceManagementClient(credentials, subscription_id)

# Create Resource Group
resource_group_param = {"location" : location}
client.resource_groups.create_or_update(resource_group, resource_group_param)


# Create Azure Storage Account
storage_account_param =  StorageAccountCreateParameters(sku=Sku(name=SkuName.standard_ragrs), kind=Kind.storage,location = location)
storage_client = StorageManagementClient(credentials, subscription_id)
storage_async_operation = storage_client.storage_accounts.create(resource_group, storage_account_name, storage_account_param)
storage_account = storage_async_operation.result()
